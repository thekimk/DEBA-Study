# %% [markdown]
# # Library

# %%
# !pip install aiohttp

# %%
# Ignore the warnings
import warnings
# warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# Auto reload of library
# %reload_ext autoreload
# %autoreload 2

import requests
from data_crawling import *

# %%
# hyperparameters
SEARCH_QUERY = "고령화"
START = "20180101"
END = "20230901"
SORT = 0
MAXPAGE = 2
SAVE = True

def get_urls_from_naverblogs_bydate(search_query, start_date, end_date, maxpage=1000):
    urls = [f'https://s.search.naver.com/p/blog/search.naver?where=blog&sm=tab_pge&api_type=1&query={search_query}&rev=44&start={i * 30}&dup_remove=1&post_blogurl=&post_blogurl_without=&nso=so:dd,p:from{end_date}to{start_date}&nlu_query={{"r_category":"29+27"}}&dkey=0&source_query=&nx_search_query={search_query}&spq=0&_callback=viewMoreContents'
            for i in range(1, maxpage)]
    
    return urls

def get_blogcount_bysync(search_query, start_date, end_date):
    url = f'https://s.search.naver.com/p/blog/search.naver?where=blog&sm=tab_pge&api_type=1&query={search_query}&rev=44&start={30}&dup_remove=1&post_blogurl=&post_blogurl_without=&nso=so:dd,p:from{end_date}to{start_date}&nlu_query={{"r_category":"29+27"}}&dkey=0&source_query=&nx_search_query={search_query}&spq=0&_callback=viewMoreContents'
    response = requests.get(url)
    data = response.text.replace('\\', '')
    start_index = data.find('"total":"') + 9
    end_index = data[start_index:start_index + 50].find('"') + start_index
    count = int(data[start_index:end_index])

    return count
    

urls = get_urls_from_naverblogs_bydate(search_query=SEARCH_QUERY, start_date=START, end_date=END, maxpage=MAXPAGE)
request = get_blogcount_bysync(search_query=SEARCH_QUERY, start_date=START, end_date=END)
request
# Out:
# 450730

# %% [markdown]
# # Naver News Crawling

# %%
# hyperparameters
SEARCH_QUERY = "고령화"
START = "20230601"
END = "20230631"
SORT = 0
MAXPAGE = 1
SAVE = True

# data loading
df_news = get_data_from_navernews(search_query=SEARCH_QUERY, start=START, end=END, sort=SORT, maxpage=MAXPAGE, save_local=SAVE)
df_news
# Out:
# URL Extracting Time:  0:00:00
# 100%|████████████████████████████████████████████████████████████████████████████████████| 2/2 [00:12<00:00,  6.04s/it]
# News Info Extracting Time:  0:00:12.080980
# Size of News Data:  20
#                    Date         Press Category  \
# 0           2023.06.30.        아시아투데이       []
# 1   2023-06-30 05:02:04    경기일보언론사 선정     [사회]
# 2   2023-06-29 14:31:01  아이뉴스24언론사 선정     [사회]
# 3           2023.06.29.          불교신문       []
# 4           2023.06.28.           MTN       []
# 5           2023.06.27.      BBS NEWS       []
# 6           2023.06.27.          경상일보       []
# 7   2023-06-26 15:09:00          한국경제     [사회]
# 8   2023-06-26 11:14:01         헤럴드경제     [사회]
# 9   2023-06-25 15:09:01          시사저널     [사회]
# 10          2023.06.30.          경북신문       []
# 11  2023-06-23 20:20:01          매일경제     [[]]
# 12          2023.06.23.          비즈한국       []
# 13          2023.06.29.     CEO스코어데일리       []
# ...
