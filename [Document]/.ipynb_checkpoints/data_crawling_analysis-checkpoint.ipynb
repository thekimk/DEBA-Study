# %% [markdown]
# # Colab에 Mecab 설치
# # 코랩에서 한글 표기를 위해 폰트 설치

# %%
# flag = True
# while flag :
#   !git clone https://github.com/SOMJANG/Mecab-ko-for-Google-Colab.git
#   %cd Mecab-ko-for-Google-Colab
#   !bash install_mecab-ko_on_colab190912.sh

#   !apt-get update -qq
#   !apt-get install fonts-nanum* -qq
#   flag = False

# %% [markdown]
# # 키워드 입력 후 크롤링

# %%
from bs4 import BeautifulSoup
import requests
import re
import sys
import pprint
import csv
import json
import pandas as pd
from datetime import datetime

result=[]

headers = {
    'authority': 'apis.naver.com',
    'accept': '*/*',
    'accept-language': 'ko-KR,ko;q=0.9,en-US;q=0.8,en;q=0.7',
    # Requests sorts cookies= alphabetically
    # 'cookie': 'ab.storage.userId.7af503ae-0c84-478f-98b0-ecfff5d67750=%7B%22g%22%3A%22browser-1625985144309-6%22%2C%22c%22%3A1626101500089%2C%22l%22%3A1626101500089%7D; ab.storage.deviceId.7af503ae-0c84-478f-98b0-ecfff5d67750=%7B%22g%22%3A%224cbe130c-6edd-d4aa-a78d-290b003c3592%22%2C%22c%22%3A1626101500094%2C%22l%22%3A1626101500094%7D; ASID=7992e0220000017aaa36664e0000004e; _ga=GA1.2.612969395.1626832328; ab.storage.sessionId.7af503ae-0c84-478f-98b0-ecfff5d67750=%7B%22g%22%3A%2228148006-e01d-7623-b7d1-b4fff0f59b4e%22%2C%22e%22%3A1627919390179%2C%22c%22%3A1627908091281%2C%22l%22%3A1627917590179%7D; MM_NEW=1; NFS=2; NNB=RDIIILNX6JCWE; nx_ssl=2; nid_inf=1665554565; NID_AUT=tP3V5ox533EjyAgkJ1JaqWEnPOhXs2hr3teD39pK972fuXqDWQZXoIOMzICJpa1A; NID_JKL=d393brIzilbjw+7TVvG0OW6Eo22+WIhQAfihItUdgbY=; _naver_usersession_=SPdJTrlTMrn8Udkyn58eo6HL; NID_SES=...; NDARK=N; page_uid=hrKUflprvN8ssNc4Muwssssss3R-382317; BMR=',
    'referer': 'https://n.news.naver.com/article/028/0002595736',
    'sec-ch-ua': '"Whale";v="3", " Not;A Brand";v="99", "Chromium";v="102"',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '"Windows"',
    'sec-fetch-dest': 'script',
    'sec-fetch-mode': 'no-cors',
    'sec-fetch-site': 'same-site',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/102.0.5005.108 Whale/3.15.136.18 Safari/537.36',
}

def news_url(query):
    page =1
    url_list=[]
    while page <= 51 :

        url = "https://m.search.naver.com/search.naver?where=m_news&sm=tab_pge&query="+query+"&sort=0&photo=0&field=0&pd=1&ds=&de=&cluster_rank=129&mynews=0&office_type=0&office_section_code=0&news_office_checked=&nso=so:r,p:1w,a:all&start="+str(page)
        response = requests.get(url,headers=headers)
        html = response.text

        #뷰티풀소프의 인자값 지정
        soup = BeautifulSoup(html, "lxml")
        # print(soup.select('a.news_tit')[3]['href'])
        #<a>태그에서 제목과 링크주소 추출
        atags = soup.select('.news_tit')
        # print(len(atags))
        for i in atags:
            if "https://n.news.naver.com/" in i['href'] :
                url_list.append(i['href'])   #링크주소
                # print(i['href'])
        if len(atags) < 15 : #한페이지에 15개나오는데, 그보다 작으면 없다고 판단
            break
        page = page + 15
    return url_list
    # 위에서 크롤링한 네이버 뉴스 url을 입력합니다.
def comment(url_list):
    total_comment = [] #모든 댓글을 담는 리스트
    for url_ex in url_list:
        url = url_ex
        url = url.split('?')[0]
        oid_1 = url.split('/')[-1]
        oid_2 = url.split('/')[-2]
        
        i = 1
        while True:
            params = {
                'ticket': 'news',
                'templateId': 'default_society',
                'pool': 'cbox5',
                'lang': 'ko',
                'country': 'KR',
                'objectId': f'news{oid_2},{oid_1}',
                'pageSize': '100',
                'indexSize': '10',
                'page': str(i),
                'currentPage': '0',
                'moreParam.direction': 'next',
                'moreParam.prev': '10000o90000op06guicil48ars',
                'moreParam.next': '1000050000305guog893h1re',
                'followSize': '100',
                'includeAllStatus': 'true',
            }

            response = requests.get('https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json', params=params, headers=headers)
            response.encoding = "UTF-8-sig"
            res = response.text.replace("_callback(","")[:-2]
            temp=json.loads(res)
            try :
                comment = list(pd.DataFrame(temp['result']['commentList'])['contents'])
                for j in range(len(comment)):
                    total_comment.append(comment[j])
                if len(comment)<97:
                    break
                else:
                    i+=1
            except :
                break

    print(total_comment)
    return total_comment


def get_news_comments(url):
    # setting
    url = url.split('?')[0]
    oid_1, oid_2 = url.split('/')[-1], url.split('/')[-2]

    i, comments = 1, [] #모든 댓글을 담는 리스트
    while True:
        params = {
            'ticket': 'news',
            'templateId': 'default_society',
            'pool': 'cbox5',
            'lang': 'ko',
            'country': 'KR',
            'objectId': f'news{oid_2},{oid_1}',
            'pageSize': '100',
            'indexSize': '10',
            'page': str(i),
            'currentPage': '0',
            'moreParam.direction': 'next',
            'moreParam.prev': '10000o90000op06guicil48ars',
            'moreParam.next': '1000050000305guog893h1re',
            'followSize': '100',
            'includeAllStatus': 'true',
        }

        response = requests.get('https://apis.naver.com/commentBox/cbox/web_naver_list_jsonp.json', params=params, headers=headers)
        response.encoding = "UTF-8-sig"
        res = response.text.replace("_callback(","")[:-2]
        temp=json.loads(res)
        try :
            comment = list(pd.DataFrame(temp['result']['commentList'])['contents'])
            for j in range(len(comment)):
                comments.append(comment[j])
            else:
                i+=1
        except :
            break

    return comments

# %%
# # 실행함수
def main():
    query = input("검색어 입력 : ")
    # query='미국'
    url_list = news_url(query)
    allCommetns = comment(url_list)

# query='미국'
query = input("검색어 입력 : ")
url_list = news_url(query)
allCommetns = comment(url_list)
# Out:
# 검색어 입력 : 세대 갈등
# ['국민의 안전을 위해 공항 건설하는데, 종교단체 지도자를 왜 만나는지요?!! 시간 끌수록 도민들 갈등이 더 깊어집니다. 빨리 국토부 회신하고, 2공항 반대하는 제주시의 기득권들에게 건설 당위성을 설득하고 갈등 봉합하는게 오지사가 해야 할 일입니다.', '', '하.. 종교까지 끌어들이네 뭐 이런 사이비가.다있누', '공항짓는데 종교인? 도지사 재누가 뽑았냐 ㅋ', '환경에 종교까지. 다음은??', '뮤지컬 이라는 새로운 장르에 당차게 도전하고 연습의 무게를 잘 알고 있는 노력하고 준비된 최고의 아티스트 김희재 의 모차르트 응원합니다', '김희재 물음표를 느낌표로 감동입니다 \n준비된자만이 누릴수 있는 도전과열정 언제나 언제까지나 응원하며 함께하며 희랑합니다 \n모차르트 는 희차르트였습니다', '사랑스럽고\n천진난만한 모습 뒤에 감춰진 \n여리고 고뇌하는 모습을\n김희재 배우만의 개성으로\n너무 잘 표현하고 있어\n감동 감동입니다', '희짜르트님 넘버넘 잘해요 표가 아깝지않을정도로 너무 잘하시고  연기표정까지 예술이예요', '첫 도전임에도 불구하고 호평을 받고 있는 볼프강모차르트 김희재 부족함은 하나하나 채워가면서\n함께해요 응원합니다', '뮤지컬이란 새로운 도전에 자신감을

# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_10272\1841322082.py in <module>
#      33  'https://n.news.naver.com/mnews/article/005/0001455243?sid=102',
#      34  'https://n.news.naver.com/mnews/article/031/0000609747?sid=105']
# ---> 35 allCommetns = get_news_comments(url_temp)
#      36
#      37 end = datetime.now()
#
# ~\AppData\Local\Temp\ipykernel_10272\1574965497.py in get_news_comments(url)
#     100 def get_news_comments(url):
#     101     # setting
# --> 102     url = url.split('?')[0]
#     103     oid_1, oid_2 = url.split('/')[-1], url.split('/')[-2]
#     104
#
# AttributeError: 'list' object has no attribute 'split'

# %%
get_news_comments(url_temp[2])
# Out:
# 0004980996 018
# ['이준석대표 응원합니다...',
#  '',
#  '민주당은 어떠케든 남탓하려하냐? 통일부나 여가부가 한일이 대체뭔데? 세금 낭비 줄이고 정부 부처도 필요없는것 다 없애고 공무원도 줄여서 나라세금좀 어껴라...국민들은 등허리가 휘어나는데 뭐 느끼는것 없는 민주당은 젊은 이준석 대표에게 많이 많이 배우거라.',
#  '이준석 생각보다 훨씬 잘하네',
#  '작은 정부 강한 정부 적극 지지한다',
#  '다른 년 놈들 반박은 모르겠고  고민정 얘는\n확실히 대가리 나쁜애네 반박이 윤석렬 부인을  갖다 붙이냐?   어휴  이런 대가리로  국회의원 하다니~  뽑아준  유권자들도  참 답답허요~',
#  '합리적으로 보면 이준석씨 이야기가 효율적으로 보이고, 이 2부처가 있으므로 해서 득이 되는 면도 있겠지만, 너무 비효율적이고, 무엇보다 반론에 대해서 설득력이 떨어지니;;;;; 이기고 지는 문제가 아니라 좀 더 국익이 되는 쪽으로 움직이는 것이 정치라 생각을 하는데~ 그런면에서 민주당보다 이준석씨의 논리가 더 합당해보이네요',
#  '',
#  '',
#  '통일부가 아니라 부칸남측 사무소아니냐?',
#  '',
#  '구구절절 이준석 대표가 맞는말 하고있고 핵심을 짚어내고있는데 세금만 축내는 민주당쓰래기들은 말장난만 하고 있구나. 그 지긋지긋한 젠더감수성 어쩌구 동문서답하지말고 그래서 도데체 여가부 통일부가 필요한 이유가 뭐냐고? 이 삶은 소머리국밥 음식찌꺼기 같은 민주당놈들아',
#  '',
#  '',
#  '이슈파이팅 이준석. 너의 정치적감각 인정할 수 밖에없다. 논리로 작은정부의 필요성을 주장하는 이준석과 그냥 이념과 감수성을 토대로 무논리 어거지로 대항하는 여당. 이미 게임은 끝났네.',
#  '',
#  '확실히 하버드는 과거 현재 미래를 볼 줄 아는구나. 필요없는 것은 부처고 공무원이고 사회단체고 과감히 없애고 그 비용만큼 국민들 세금 줄이고 자유시장경제에 맡기고 정부는 작은정부 책임있는 정부가 되야한다.',
#  '통일부 여가부폐지 적극찬성합니다 작고 강한정부 이준석대표님 아주잘합니다',
#  '통일부는 외교부가 맡고 여가부는 보건복지부가 맡으면 된다. 비대해진 정부부처부터 개혁하여 국고낭비와 정책혼선을 막는것이 맞다. 이준석 판단이 옳다!!',
#  '',
#  '',
#  '이이녕 반론봐ㅋㅋㅋㅋㅋ 꽃 받는 영상 찍고 편집하는 거 자체가 세금 낭비라고 하는데 거기서 젠더 감수성이 왜 나와ㅋㅋㅋㅋㅋ 지능이 모자라면 진짜 하지마라. 너 같은 거 장관이라고 관용차 타고 밥 쳐먹고 디저트로 커피 사쳐먹는 거 다 내가 낸 세금이다. 없애야 돼 그래서.',
#  '국방부 있어서 국방되는거 맞고. 경찰있어서 치안유지되는거 맞는데 통일부있어서 북한에 상납만 있잖아. 차라리 대등한 외교하는 외교부에 북한관련 부처 넣어라. 이게 뭐냐. 북한식민지도 아니고 북에서 뭐라고하면 문재인부터 벌벌. 이딴나라가 속국이지 자주국가냐.',
#  '이준석 논리에 다 찌그러지네~ ㅋㅋㅋㅋ\n애초에 머리싸움 논리싸움으로는 상대가 안되는데 고민정 이인영 헛소리에 가만있을수 없지.\n통일부 여가부가 어떤성과를 내왔는지 자료공개해.\n저기 인도네시아 현지여성 지원한다는 쌉소리하지말고.',
#  '작은 정부 지지합니다 \n\n국회의원 수만 늘어났고 국민들을 위한다고만 말로만하지 자기들 밥그릇은 늘 채워왔음\n 코로나로 국민은 힘들어죽을꺼 같은데 국회의원들 정말 공감할까?\n국회의원들 특권과 수당 월급을 내려놓는다면 그 수가 문제일까? \n국민들이 납득할만한 실적과 특권에 맞는 일을 했으면~',
#  '통일부? 거기 모하는데고? 정은이한테 쩔쩔메는부서?',
#  '고민정 모더나 2000만명분확보했다며? 어디로 갔냐 니가 빼돌린거냐 책상에 엎드려 낮잠 그만 자고 백신 가져와라',
#  '통일부 존폐어부를 떠나 김여정 하는 말에 대응이나 좀 잘 해주라  문통 국격이 있지 소대가리가 뭐니?',
#  '고민정 뽑은 국민들도 반성해야할듯~',
#  '여가부, 통일부 전부 한자리 꽂아줄수 있는 정치권 먹거리거든. 이준석은 진짜 애국심으로 말하는거다. 아직 때 덜 묻었거든',
#  '고민정은 국회의원수준미달이다   자숙하고 자중하라 피해호소인 고민정  국회의원사퇴하라',
#  '',
#  '상식선에서 두 부처가 과연 있어야되는 지 문제를 지적하고 작은정부 정책을 말하는데 그 문제에 대한 논리적 반론도 못하면서 왜 개떼처럼 짖어댈까요? 국방부 있다고 국방되냐는 식의 유아적 반론뿐인 저질, 모지리들의 얘기는 들을 것도 없습니다. 잘못에 대한 반성도 없고, 수리해서 쓸 수도 없는 저 더러운 것들은 멸족만이 답이라니까요.',
#  '',
#  '역시 민정씨는 뭐가뭔지~ 그냥 가만히있기는\n그렇고 한마디 한다는게 ~\n뮐 덮으려는 거라네  ㅎㅎㅎ  \n그냥 일이나 하시지,  뭘일을 하는지도 모르겠지만서도~  난감허네~~',
#  '민주당이 부들거리면 뭐다? 제대로 가고 있는거',
#  '다 맞는 말이구만. 통일부 없어도 외교부에서 같이 담당하면 되고 여가부가 한게 뭐 있냐 박시장 사건때 입꾹 닫고 여성들을 위해 한게 뭐가 있냐. 다들 산하 부서로 이동시키고 나라 세금만 축내는 인원들 다 감축시키고 건물도 세줘라. 세금 낭비다.',
#  '합리적이고 이성적인 의견입니다. 이준석 대표 앞으로가 기대됩니다. 헛소리들 신경쓰지마시고 국익을 위해 일해주세요',
#  '',
#  '',
#  '',
#  '강병원의원님! 국방부 있어서 나라 지키고요. 경찰 있어서 치안이 이만큼 유지되거든요. 통일부와 여성부가 도대체 한것이 있나요? 통일부가 아니라 북한찬양부고 여성부는 여성우월부나  여성열등부 아닌가요? 그런돈 쓸바에야 청소년 문제가 너무 심각해서 가뜩이나 애도 안 낳는데 갈등만 불러 일으키고 애들 맨날 자살하고 죽음. 뭐가 더 중요합니까? 통일 될거 같으면 그때 만들어도 된다고 봅니다. 역사의식? 북한찬양하면  역사 의식 높은건가? 그런 역사의식은 안 높아도 됨.',
#  '통일부, 여가부만 없애지 말고 국회의원 없애버립시다\n맨날 싸움만 하는 사람들....',
#  '논리적으로 반박을해라 조국 같은 놈들아',
#  '왜 쥐닭때는 함구하니 있으니 그때 좀 하지',
#  '대만에 휴전선 없으니 우리나라도 휴전선 없애야 겠네..ㅜㅜ 대만과 중국이 우리나라처럼 분단된건가?..한심한 발상..',
#  '좌삐리들 총출동이네 ㅋㅋㅋㅋ 준석아 싹 깔아 뭉개라 대한민국에 1도 도움안되는 좌삐리놈들...',
#  '이준석 너무 똑똑해.',
#  '경찰 있으니 치안 안정된거 맞고요. 국방 있으니 침공 막는거 맞고요. 통일부 있다고 통일된거 없고요.오히려 남북연락사무소나 파괴된거 맞고요. 정은이 돈줄 아니었던가요.',
#  '고민정  생각하는거  하고는  찌질하고 웃겨    그냥  조용히 잊혀져 있는게  좋을듯',
#  '와...살다살다 이인영 입에서 "부족한 역사의식" ㅋㅋㅋㅋ',
#  '이참에 빨리 통일부의 숨겨둔 실적을 밝혀서 이준석대표 코를 납작하게 만들어줘!',
#  '이 준석 대표 응원합니다',
#  '누가 봐도 맞는 말만 하긴 하네~ 늙은 정치인들 헛소리 하는거 보다 훨씬 와닿을 소리하는구만~ 물론 통일부를 해체 하기엔 이런저런 문제점들이 많기에 어렵겠지만~ 여성가족부는 선진국중 한국만 있다~ 김대중이 만들었다....왜 만든건지...너무 형평성에 맞지 않는 부서....그리고 여성주차칸이 웬말이냐...여성이라고 무시당하는 세상이 아님..평등하기에 없어지는게 맞지~',
#  '이건 이준석 말이 맞다',
#  '통일부가 인민무력부 대남 선전선동부 남조선지부가 맞잖아? 아니었어?',
#  '이준석대표 기대이상.....민주당 반론하는 수준이 콘대수준 ㅋㅋ',
#  '이준석씨 응원합니다',
#  '',
#  '준스톤 이정도면 진짜 인피니티 5대 스톤보다 강한거 아니냐??혼자서 간소한 몇마디로 정치 거머리들 학살해버리네 ㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋㅋ',
#  '',
#  '통일부에서 통일을 위해 한 업적이 도대체 무엇인가?\n북의 눈치나 보고, 갖다 바치지 못해 안달하는 것이 통일을 위한 것으로 착각하는 이인영 등을 보면서 염증이 왜 안 생기겠냐?',
#  '한심한 더듬어당....',
#  '',
#  '국회도 별로 하는일 없으면 없애지?\n그리고 가성비도 체크해야할 일.\n무기도 당장 하는 일이없다고 없앨 것은 아니다.\n만약을 위해서 필요한 것.',
#  '국회도없애라  지들 이속이나 챙기고 싸움질만하는 넘들이 세비만 축내고있으니 작은행정부 작은국회',
#  '',
#  '진짜 농담이나 화풀이가 아니고 국회의원 시,구의원 그리고 공무원 다 줄이거나 없에야 합니다.\n그리고 이런 저런 잡대학 다 없에고 특성화고 활성화 해야 합니다',
#  '민주당은 조선시대에 같혀 있는것같다',
#  '민주당이미지= 꼰데들의 집합소ㅋㅋㅋ\n언제부터진보가 꼰대짓하기 바뻣냐ㅋㅋ',
#  '',
#  '',
#  '잘한다 이준석 화이팅!!!!',
#  '',
#  '',
#  '',
#  '',
#  '고민정 대단하다 음모론 ㅋㅋ 클라스 어준이 급인데?ㅋㅋ',
#  '정치무능,돈으로 해결하지  말아주세요.\n장관자리 늘리지말고,연금축내지말고,혈세낭비하지  말고,,,\n작은나라가 장관도 많고,부처도 많고,,\n차기정부땐 정리해서 작은정부만듭시다.\n남는 돈으로 복지에쓰면 좋을둣',
#  '당대표있다고   당제데로 ㅇ돌아가냐?  당대표   해산하고 그만둬라',
#  '',
#  '',
#  '',
#  '여가부는 이해가 가는데 통일부에 대해 업무적으로 접근하는건 문제가 있다고 봄. 비록 나이가 어려도 최소 당대표라면 보다 넓은관점으로 정치관을 고민해야 한다 생각함. 대한민국이 일개 기업도 아니고 ,비록 돈에 환장한 자본주의 국가이긴 하지만.. 업무적 관점에서만 접근하는건 당대표가 고민할부분이아니라 실무진들이 고민할 부분이지.  남북간의 문제는 일부 지지층에게는 서로 다른나라의 문제겠지만 대한민국 미래와 관계된 문제임.독도 문제만 봐도 우리가 모른체하든 뭘하든 우린 항상 일본의 독도에 대한 반응과 세계 다른나라의 의견에 항상 예민하게',
#  '이준석이  맞는말 한거 같은데 거기에 반박하는 건 무슨 말도 안되는 ... 내로남불',
#  '일당백 이준석 ㄷㄷㄷ 남탓 만진당 다덤벼',
#  '통일부,여가부 폐지 대찬성!',
#  '이준석은  진짜다',
#  '허접스런 두뇌에 촌시런 감성팔이ㅡ뭘 덮고자??? ㅉㅉ한심스런 뮤뇌 수준의 인식에 실소를 금하지 못하네 ㅡ 그저 철밥통ㆍ 혈세낭비 부서 통일부,여가부 등은 폐지되어야 한다ㆍ',
#  '어린넘이 선창하면 태극기 노인네들 좋다고 복창 으이구야',
#  '사고가 편협하고, 권력잡겟다고  시야가 좁다. 선동과 모해가 정치만은  아닌데. 젊은데 신선함도, 역사의식도,  혁신도, 참신함도 없다. 어디서 듣긴들어 말로만 떠들고,  말장난으로 딴지걸기나하는, 달을 보라는데 손톱이 길다고 질척거리는 오래된 수구정치 냄새가 많이나 역사를 돌아보게함, 젊은 정치가들의 모습. 코인, 세치혀, 사이비, 헛발질',
#  '또 또 말돌리기 ㅋ\n군대가자',
#  '여가부는 진짜 쓸데없는 조직운영이다',
#  '시대의 흐름에좀 맞추자',
#  '아주 벌떼같이 들고 일어났네.하나같이 어스레기들이 마치 이때다 싶게 그 잘난 입으로 한마디씩 지껄이는데 그러게 진작에 잘 좀 하지.내가 보기에도 그 두 부서는 그냥 자리만들어즌것 같은더...한마디로 이니한테 잘보이면 그냥 시켜주는 자리...',
#  '똑똑하네. 전혀 꿇리지 않아',
#  '더덤이당이 한일은 포퓰리즘에 마타도어 외에 한일이 없다, 안되면 편가르고 남탓하고 이렇게 하니 부동산이고 원전이고 대북문제도 정은이 지령받아 일하는 같고',
#  '역시~! 생각도 판단도 되받아치는것도 획기적인 이준석대표   응원힘....  엄지 처~억!지지합니다 화이팅!!!!!!',
#  '',
#  '국방부는 국방하고 있지.... 경찰은 치안하고 있고... 강병원은 뭔소리하는거지..',
#  '',
#  '맹구는 누구인가 ? 너무 많아 ~ 한둘도 아니고 모지리브라더스, 맹순이 맹구들 ~ㅎ',
#  '혈세낭비 통일부 폐지 골수빨갱이 이x영 감옥',
#  '이준석.. 시원하게 얘기 잘한다.. 고민정은 그냥 찌그러져 있지? 덮기는 뭘 덮어..',
#  '인인영 북한에 백신주자는 헛소리민 지껄이니',
#  '',
#  '준석이가 똑똑하긴하네. 틀린말 하나없다. 비효율적인부처는 과감하게 개선해야된다.',
#  '더불어~ 만지작만지작~~ 주물럭주물럭~~ \n내로남불! 부동산투기는 나만 몰래!\n주둥이만 공공이랴 뻔뻔 민주 뽕숭아 학당~~예~~~',
#  '통일부보다 검찰 먼저 폐지하는게 ~~',
#  '이준석... 정말 맘에든다',
#  '통일부,여성가족부 없에든지 축소시켜라ㅡ가득이나 공무원 많아 세금도 많이 나가는데',
#  '좌빨들 한계가 계속해서 드러난다',
#  '',
#  '준석이는 이미 소수 인터넷여론 몰이 하다보면 다수를 이기는 경험을 해봤지. 김어중이떠중이 나꼼수가 전에 한거와 같이 한국은 적극적개돼지60%에 온건한 개돼지35%인 나라다. 즉 60%는 아무생각이 없고 30%는 여론조작하면 따라오는 종. 결국 소수로만 인터넷 여론 조작하면 그걸 다수인지 알고 30%는 따라오고 60%중 절반씩 개눌당문주당 갈라지니 총 60%는 먹어서 이긴다. 만약 준석이가 우연이 아니라 이걸 잘한다면 준석이의 지지를 받는 사람이 다음 대통이네. 생각이 있는 자들은 다들 과감히 비전을 던져라. 작은정부처럼 옳은 비전을',
#  '',
#  '',
#  '',
#  '자리만 보존하고 국민혈세로 장관 급여주는 여성부 통일부 통폐합이  맞다 국민 여론조사해봐라',
#  '답변을 주고 자료를 줘야할 시기에 ,  협작계략을 보이다니~,  그동안 어떤 정치를했는지  알수있겠구나.  많는 부채를 가졌으면 줄이기위해 고민하고 아파해야할 집권당이 ,노력은 보이지않고 결국은 남탓만  하는 모습에 기가막힐 뿐이다.  너네들이 적폐 맞지?? 그래서 적폐놀이로 국민눈을 속여온것 맞지??',
#  '미안하지만 이인영이 통일부장관인거 이번에 처음 알았다..정치에 무관심하다고 비판해도 할말없는데 그만큼 존재감도 멀하고 있는지도 모르겠다',
#  '',
#  '민정아   넌 박사근처에도 못가  대가리 나빠서,,,',
#  '시원하다..',
#  '데모만하던 무식한 이인영이 나이만 처먹었지 아는 게 있어야지! 아는 거라곤 지밥그릇이지! 퉤퉤 쑤렉이들!',
#  '윤석렬의혹이란것중에 팩트가 있는것이 무엇인가? 또 윤석렬 자신의  의혹이란게 있나?',
#  '이준석,  너희들은 유튜브에서 윤석열을 검색해보라?  \n알면서 모른척하니,  알고도  배짱이처럼 노니?  국민들이 무식하다고  우기대지 말고,  젊은이가 보수를 개혁할 줄  알고 기대했는데,  그놈이 그놈이네.  너도 공정을 말할려거든,  사과부터 해라.',
#  '문재인 정권에서 통일부는  김정은비유맞춰주는부서로 전락했다  .     이인영  통일부가  문재인 정권에서 뭘했는지 열거해봐라    통일부는   북한도우미일뿐이였다  .\n 그러니  통일부 폐지해도  좋다는것이  국민들 생각이다  .',
#  '이준석아  이명박 박근헤 시절엔 한마디도 못하다ㆍㆍ 그땐 너무 잘한거니',
#  '야. 정말...  우리 이준석을 내려준 이에게 감사하고 싶다. 그 패기. 영원히 지켜주시라. 응원한다. 우리 대표님.',
#  '',
#  'ㅎ 넘 #똑똑해  #사이다 #뚫어뻥',
#  '속시원하게 말하네 이번에 대선 출마하면 밀어준다',
#  '',
#  '',
#  '이준석화이팅!!👏👏👏 솔까 요즘세대들은  통일도별관심없다 중년인나도 남과북 이젠 서로간섭말고 각자알아서살았음한다',
#  '개거품',
#  '민주당의 정치는 구닥다리에 도덕성도 없다. 늙고 교활하고 썩은 정치인들은 퇴장준비를해라.',
#  '뭐눈엔 뭐만 보인다고...색안경 자체가 본인들이. 주로 쓰는 전법인지라',
#  '',
#  '',
#  '반박 꼬라지가 진짜 어버버종합선물셋트네',
#  '',
#  '쥰서기 논리적으로 말 잘하는것 하나는 기가막혀서.상대들 죄다 말문막힌 징징이로 보임ㅋㅋ',
#  '군대나가 이 ㅅㄲ야',
#  '세치혀로 망할자',
#  '여가부폐지 통일부폐지  이준석씨??  얼마나최선을다할려고 그래도국민의힘인거아시죠?? 좀있다가는 대통령자리도필요없다하겠어요?? 국민들착취억압안할정책어디없습니까??',
#  '',
#  '',
#  '',
#  '시레기 다되가네 준석이 ㅋ ㅋ 역시 국민의짐 당원이야 좀더하면 일베,친일파,태극기부대  다모이겠네',
#  '이재명후보 종잣돈9억만들었네요 국민의힘잘보시라 당신들은 당신들만을위한 정권교체란 단어만 머릿속에 박혀있을뿐',
#  '이준석이  잘  한다.\n  화이~팅!\n  대선까지 고~고~고',
#  '',
#  '배운게 없어서 반박도 못하네 그져 남탓',
#  '',
#  '',
#  '',
#  '',
#  '준석이 말이 더 설득력이 있다....',
#  '작은정부 공감하며 환영 합니다.',
#  '민주당놈들 논리가 희한하네 논리에는 논리로 반박해야지 어거지로 싸잡아대네',
#  '여가부와  윤석렬이 왜 연관지어지지?   대체 이준석하나도 못당하는  더듬이당 국개의원들보니 가슴이 답답하다.... 제발 투표잘하자...개돼지서민들아...쫌',
#  '고민정은 왜ㅜ나대냐 꼴에 국회의원이라고 벳지 달았다고 기본도 안되는게',
#  '통일부가 무슨일을 했습니까? 그돈으로 대한민국 어려운 분들부터 돕는게 낳다...',
#  '',
#  '여가부 ᆢ통일폐지론 ᆢ복주머니?',
#  '그래 좀더 과감하게 나가야 문정권 정신 차린다',
#  '국민의 혈세를 어찌하면 정은이에게 바칠수 있을까 남낮으로 연구하느라 고생이 많다.',
#  'OOO들 그저 선동하고  말도안되는 잡소리만하고 \n실적을 내놔바라 북한에 퍼준거라도.ㅉㅉ\n대가리가 딸리제 젊은 아이한테?민주당 쓰레기들ㅗ',
#  '이준석 화이팅  잘하고 있다  세금아껴써라',
#  '',
#  '이준석 Nice  shot!!!  일당 50만이다.',
#  '여가부와 통일부는 실적과 업적으로  반박못함  일한게 없으니까 그냥 국민세금만 쌈짓돈으로 쓰느라 바쁨 ㅋㅋ',
#  '실적이 없아 슬픈 부처요~~',
#  '무식한 민주당 어른이들...\n비유를 들걸 들어라...ㅠㅠ\n초등생 수준...',
#  '',
#  '이인영 ㅋㅋ 종북 개다리',
#  '',
#  '야 웃기는 놈아, 지랄들 하지 말고. 다음 대통령 선거에  니네 후보가 되어서  그때 없애든가  하셔.  지금 말갖지도  않은  말 가지고 혼란 부추키지말고.',
#  '세금낭비 통일부 해체해라',
#  '작은정부 응원합니다 국민들의 가처분소득 증가가 필요합니다',
#  '불필요한 먹튀들은 없애자\n응원합니다',
#  '',
#  '민주당   니들은    북한가서     이딴짓거리했다가는     전부  총살감이다~~~\n거짓말부정부패깡패집단리    뭐라카노~~~~\n입들닫고      반성해라',
#  '',
#  '',
#  '더불어민당너희들은.말로서는이준석한테못이긴다그냥조용히있는게2등감',
#  '',
#  '중요한 곳에 나의 세금이 올바르게 쓰이길 원한다!',
#  '이대표 홧팅!!',
#  '이준석. 이번에야 말로 정권교체 해야된다는 국만의 명령이다',
#  '',
#  '',
#  '바지사장',
#  '작은 정부 찬성. 큰정부했더니 그것들 고액연봉주고 관용차,관사 주느라 국민혈세 뜯어간거밖에 더 있어? 통일부,여가부는 없애고 산하부처로 들어가도 충분함을  그 부처장관들이 몸소 보여줬다. 경찰과 국방부를 비교하는 돌  대가리 ㅋㅋ비유법 좀 더 연구해와ㅋㅋ더불어 모자란당',
#  '',
#  '강병원이가 박근혜 "씨" 라고 했다는 거, 사실이냐? ㅋㅋㅋ 문재인씨라고 불러도 될 근거를 만들어 주는구만? ㅋㅋㅋㅋㅋ 어이, 문재인씨?',
#  '',
#  '이번 대선에서는 이걸로 국민시선 돌리려고? 그 당은 매번 왜그러냐? 정상적으로는 뭐가 잘 안돼? 윤석열은 니들 당도 아니래매?',
#  '참 그지같은 같은 색히들  세상에 필요없는걸 폐지하자는데??별걸다 갓다가 붙이네;;에라이 개정부;;:',
#  '논쟁을 피하려면 통일부와 여가부 업무실적을 국민에게 알린후 이준석 대표의 말에 반박해야 국민이 존재의 이유를 이해할수 있지않을까...',
#  '이준석  지지한다... 여가부는 암적 존재다...국민 피 빨아 1조원 어디에 사용하나?  통일부도 비스무레하다',
#  '놀고있네  당신네들하고는  격이달라',
#  '여가부 꼴폐미사관으로 본다면 통일부에서 여자들에게 꽃을 선물 하는 것은 여성비하 아닌가? 몇년전 꼴폐미들이 미쳐서 날뛸때 여자보고 이쁘다고 하면 여성비하라고 개 난리를 치더만.......',
#  '강병원 고민정 이름만 들어도 섬뜩하고 더럽다',
#  '이시키도점점 스레기로 변하는군!!!@@',
#  '',
#  '',
#  '',
#  '',
#  '민주당은 이미 봉숭아 학당~',
#  '준석이가 누구 위하는 사람 아냐 .  머리좋은 애들은 누굴 위하고 그러질 않아',
#  '통밀부없애고독도수호부창설해라준석아',
#  '고민 안하는분은 아직도',
#  '',
#  '이준석 하나에 다들 꼼짝 못하네~~\n워낙 맞는말 하니…',
#  '저 모지리 불한당들이 하는 역사인식, 사회인식, 민주..  어쩌고 하는 것은 진정성이 1도 없는 말장난에 불과합니다. 피해호소인 고씨는 짜증니니까 논점 흐리지 말고 찌그러져 있음 좋겠다.',
#  '',
#  '북한전쟁물자 악착같이 퍼주는  \n통일사칭부\n수구꼴통  문죄인정부가  폐지할려 하겠어요?  정권끝나 특검하면  문죄인이가 얼마나\n 북에 퍼주었는지 알면  놀라 자빠질겁니다',
#  '빨갱이들 지들뜻대로 안되니깐 논리도 없는 괴변 늘어놓는거봐라 세금이나 빨아먹는 벌레들',
#  '통일부가 하는것이 뭔지 궁금함진짜로  난  솔직히  통일 바라지도 않는다  왜   북한  한테  찔찔매고  중국한테 찔찔매고   중국도  서해안에다 원전을 무지 짖는데 왜  탈원전하는건지  진짜  대가리에  뭐가 들어 있는지 궁금하다  진짜',
#  '여가부 통일부 일단은폐지가 맞고요\n여가부는 여성인권보다 정권 딸랑이부에 세금만 축내고 통일부는 부칸정은이 짝사랑하는 부냐 남.북 사무소 폭파해도 그만 삶은소대가리 망발에 국격을 비난해도 그만 그러니 국민 피.땀흘려번 돈으로 세금내는데 축내지 맙시다.',
#  '왜 반론을 못하고 엉뚱한소리하겠냐ㅋㅋ 맞는말이니까',
#  '',
#  '',
#  '주머니 3개중 1개라 봅니다',
#  '통일부가 무슨 일을 했는지 궁금합니다 정말',
#  'ㅋㅋㅋ 전라 경상이나 통일시켜라...야바위꾼들아',
#  '...노이즈마케팅하나...',
#  '',
#  '고민정\n정치판에 가더니  변질되도엄청 변질됬네~',
#  '',
#  '',
#  '이 인간들 세월호 선동질로 정권 잡드만, 선동질하믄 다 되는줄 아나보네~ㅋㅋ 조국은 딸년이나 재산증식에 직접 관여 했고! 윤석열은 장모사건이나 부인 논문에 믄 관여를 했노? 그런식으로 선동질 하면 국민들이 또 속을거라 생각하나?! 윤석열한테 뭐 하나도 안나오니~처가집가지고 지롤하네~ㅋㅋ 근데 진짜 웃긴건! 검찰총장 청문회 때 민주당 인간들이 윤석열 문제 없다고 안했나?ㅋㅋㅋ 근데 이제와서 문제가 되나?! 윤석열이든 아니든!! 정권교체는 사실이고! 문재인은 감옥간다!! 알겠냐!!',
#  '통일부에 비밀이 많나보네.\n대깨들이 다 달려드는거보니,,,ㅋㅋㅋ',
#  '고민정 수준봐라',
#  '아오사이다~~~',
#  '이런게 이준석씨 꾀주머니?',
#  '',
#  '통일부 여가부 내 세금 시ㅂㅅ끼들아',
#  '',
#  '',
#  '정치를 말장난쯤으로 아는 듯 물에 빠지면 주디만 동동 뜰거다 이준석',
#  '',
#  '저런걸 당대표로두니 국민이 무슨 국회의원들을 믿고살겄냐  하긴 저놈은  국회의원도 아닌놈이지',
#  '국찜당 폐지원합니다',
#  '이준석을 지지한다.',
#  '',
#  '졸리 졸리 지우려  더 깊어가네  졸리졸리~~',
#  '이대표님 힘내세요',
#  '그래 하던대로 계속 시비 걸고 싸우셔들. 불구경 하다 골로들 가께. 그냥 삼국 시대로 돌아가는건 어떨까 싶은데. 외척 끌어들여 또 한바탕 하고. 역사는 돌고 돈다매',
#  '관종질은 적당히! 과유불급.',
#  '준석아. 정보처리기사 자격증 부터 공개하고, 시국이 어떻든 저텋든 해아 되는게 일반상식 아니니. 절은 꼰대 가터.',
#  '이대표.기대보다 쵝오!!\n53세 아저씨가 응원합니다.',
#  '쓰레기들  꼴에 언론이랍시고  석열이개가 말하는 공정이 무슨 공정이냐  저에처가에는 관대하기 한이없다  언론또한 마찬가지다  무엇이 공정하냐  저가하고싶은 말만하는  똘아이같다   자기  장모 사기나  처 쥴리 주가조작의혹  논문표절 사기집단 어디다 대고 공정을  씨부리냐',
#  '',
#  '',
#  '윤도리도리 충견 이준석으로 되어가네',
#  '',
#  '',
#  '사기꾼들이 정권을 잡고있으니..이나라는 어디로 가는것인지~',
#  '',
#  '이인영은  도대체  업적이 없다,,, 무식해서 쌀만 퍼주자다,, 북한이 거지냐?',
#  '이준석 응연',
#  '국민의 짐당도 페지하자',
#  '어린ㄴ이 대표돼서 처음엔 신선한맛이 있었는데  갈수록 보꼴  꼰대짓만 하는게 국짐당 틀을 못벗는구만',
#  '좀 지나면  국가도 없애자  할 놈이네',
#  '내참 어린놈 주둥이로나불대는거에  무시하려하는데   한심한놈일세  아니 여가부있다고 젠더갈등안없어지고  통일부있다고  통일해결안된다고?  진짜  내아들같았으면 귀빵맹이를...그 야당대표란놈이 할말이냐?  참걱정된다  크따위  논리면 대통령있다고  민생해결안되고 기재부있다고 나라살림 안되고  가장가까운 니놈이 야당대표된다고 야당 바로안잡히는데 그런논리면 세상에 존재할게 뭐가있냐?  무슨 말같지도않은 개소리같은걸  당대표란놈이 함부로지껄이냐',
#  '자식같은 대표에게 질질 끌려다니는  국찜의원 나리들 이번에도 졌소. 여성표 다도망갈듯',
#  '',
#  '준식이 넌 너무 촉새가 되어가는구나 당대표가 넘 가벼워 언행이~원래부터 유촉새꽈인건 알았지만 요즘 넘 심하다 이기',
#  '',
#  '진짜 세상이 어찌돌아가는지 정치물론 나도 모르지만 윤 준석 찬양하는 애들대부분 그냥 가짜뉴스듣고 코로나땜 힘드니 열광하고 니네가 역사를 알기나 하니?',
#  '',
#  '준식이 넌 너무 촉새가 되어가는구나 당대표가 넘 가벼워 언행이~원래부터 유촉새꽈인건 알았지만 요즘 넘 심하다 이기',
#  '',
#  '진짜 세상이 어찌돌아가는지 정치물론 나도 모르지만 윤 준석 찬양하는 애들대부분 그냥 가짜뉴스듣고 코로나땜 힘드니 열광하고 니네가 역사를 알기나 하니?',
#  '',
#  '',
#  '',
#  '아직 공부를 더해야 될거 같네!  미래 통일을 아예 포기하자는 예기인지? 대만을 왜 비교 하냐?  상황이 유사하다면 모를까?  아직 이산가족들도 엄연히 생존해있는데! 통일을 향한 정책적인 새로운 아젠다를 만들어내고. 재난. 질병등 어려움에 처했을때 상호인도적인 각종 합의나 협약, 공동성명의 이행등 주도적인 통일지향정책은 지속적추진이 요구된다.',
#  '경험이 없으면 안돼요\n국민의짐 언제 국민의 힘되나요?',
#  '초딩 따릉이 ㅍㅎㅎ',
#  '석아..네가 봉숭아학당을 알어?\n봉숭아학당을 모욕하지 말어~~이 시끼..',
#  '국찜 젊은이에게 끌려다니는꼴보니 배바 산으로갈듯',
#  '',
#  '',
#  '윤석렬 의  자신과. 처.장모  숼드치는  이  준석은    군대 다시가라!',
#  '준석이는 아직 어린 아이 응석 부리는듯한 말만 하네\n  정말 대책이 필요없는 x',
#  '군대도 안갔다 온 젊은 넘이 통일에 대한 인식이  제대로 있는지.',
#  '젊은이기 거만하고 건방지다 생각좀 하고 토해라',
#  '',
#  '',
#  '이만큼 더불당에서 이대표를 까내리려하는건 그만큼\n일 잘한다는 소리, 맞는소리를 한다는 너낌 팍팍 드는건 나만그런가',
#  '야가 젊어서 기대좀 했는데 정신 500년 나간 놈이구만 하라는 민생은 안보고 민초들하고 상관도 없는 직제 개편 할라고 하네  에끼 이놈아 어린놈이 ...  니가 대통령 되면 그때 해라  못된 송아지 엉덩이에서 뿔난다더만 니놈이 그놈이구나',
#  '',
#  '준석이 요노마도 서서히 맛탱이 가고있다.\n꼴보수로 회기중.',
#  '통일부를 폐지? 하라고? 나는 국민의 힘이 없어지면 통일부가 저절로 필요없어지리라 본다',
#  '',
#  '국힘당부터 폐지해라ㅋㅋ',
#  '이준석대표 금방레임덕오것다^^',
#  '우리나라 대기업들이 세계 일류기업 소리를 듣기도 하지만 세계 인류대접을 받지 못하는 것은 분단 국가이기 때문이다.   대한민국 막강한 제1야당 대표인 이준석은 크게 실언을 한거다. 나는 이준석 지지표시를 많이 했지만 이제는 고만 할란다.  너무 어리석어서 좀 두보 봐야긋다.',
#  '',
#  '',
#  '',
#  '니 애비애미  이젠 필요없지?.',
#  '',
#  '없어도 될 부처를 왜 만들었나 생각해봐야지 지가 대통령 다된 줄아네.이럴려구 대표로 뽑았나.',
#  '이준석,군대도 안간 인간이 안보에  대해서 감히 말할 자격이 없다,군대를 왜 안갔다  왔는지 국민들은 알고 있다,']

# %%
# 그 후 분석을 위한 각종 라이브러리삽입
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import urllib.request
from collections import Counter
from konlpy.tag import Mecab
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
# 만든 리스트를 데이터프레임으로 만들어서 분석해야함.
cols_name = ["reply"]
total_data = pd.DataFrame(allCommetns,columns=cols_name)

print(len(total_data))
total_data[:5]
# Out:
# 9475
#                                                reply
# 0      원전에 있어서 안전은 최고우선시되어야하는데 안전을 중시하지말라니~~~기가차네~~~
# 1  안전 중시 안 하면 후쿠시마처럼 될라고? 제정신인가? 일본 좋아하는 건 알겠는데, ...
# 2                        우리 대통령님 잘 뽑아나서 나라꼴이 잘돌아가네요ㅋ
# 3                         석열아~  핵 폐기물은 용산청사지하에 폐기하자~
# 4                 나라를  쑥대밭으로  만들  사람일세. . .ㅠ.ㅠ\n갑갑허당

# %% [markdown]
# ## 2) 데이터 정제

# %%
# 1208중에 743빼고는 나머지 다 중복
total_data['reply'].nunique()
# Out:
# 7640

# %%
# reviews 열에서 중복인 내용이 있다면 중복 제거
total_data.drop_duplicates(subset=['reply'], inplace=True)
print('총 샘플의 수 :',len(total_data))
# Out:
# 총 샘플의 수 : 7640

# %%
# null값 유무 파악
print(total_data.isnull().values.any())
# Out:
# False

# %%
#데이터 정제
#정규 표현제을 사용하여 한글을 제외하고 모두 제거해줍니다. 또한 혹시 이 과정에서 빈 샘플이 생기지는 않는지 확인
# 한글과 공백을 제외하고 모두 제거
total_data['reply'] = total_data['reply'].str.replace("[^ㄱ-ㅎㅏ-ㅣ가-힣 ]","")
total_data['reply'].replace('', np.nan, inplace=True)# 공백Null 값 제거
total_data = total_data.dropna(how='any') # Null 값 제거
print(total_data.isnull().sum())
# Out:
# reply    0
# dtype: int64
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: The default value of regex will change from True to False in a future version.
#   after removing the cwd from sys.path.

# %%
# 형태소 분석기 mecab /백임의 토큰화 테스트
from konlpy.tag import Okt
mecab = Mecab()
okt = Okt()
print(okt.morphs('먼소리야.. 떨어지면 물타야지... 10% 팔고 떨어지면 개이득'))
# Out:
# ['먼', '소리', '야', '..', '떨어지면', '물', '타야지', '...', '10%', '팔고', '떨어지면', '개이득']

# %%
#불용어 제거
import nltk
nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
#불용어를 지정하여 필요없는 토큰들은 제거
# stopwords = ['도', '는', '다', '의', '가', '이', '은', '한', '에', '하', '고', '을', '를', '인', '듯', '과', '와', '네', '들', '듯','할','냐','수','아','그','했','어','기','만', '못','지', '임', '게','있','거','면','없','으로','나','것','로','는데','안','되','에서','겠']
stopwords = '도 는 은 면서 보다 된다 다 받 뽑 개 살 합니다 데 이게 좋 앞 함 먹 긴 잡 남 놈 때문 모르 버리 는지 짓 라도 맞 음 았 됨 은데 텐데 아서 아라 마 쓰 걸 라는 니까 어서 나오 다는 번 온 다는 의  가  이 한  에  하  고 ㅋㅋㅋ ㅋ ㅋㅋ 을  를  인 으 듯  과  와  네  들  듯 할 냐 수 아 그 했 어 기 만 인데 해 해서 더 말 그냥 었 못 지  임 않 니 주 보 서 라고 한다 뭐 대 으면 해야 건 든 두 같 네요 다고 된 치 이나 내 한테 게 있 거 면 없 으로 나 것 로 는데 안 되 에서 겠 아 아이구 아이쿠 아이고 어 나 우리 저희 따라 의해 을 를 에 의 가 으로 로 에게 뿐이다 의거하여 근거하여 입각하여 기준으로 예하면 예를 들면 예를 들자면 저 소인 소생 저희 지말고 하지마 하지마라 다른 물론 또한 그리고 비길수 없다 해서는 안된다 뿐만 아니라 만이 아니다 만은 아니다 막론하고 관계없이 그치지 않다 그러나 그런데 하지만 든간에 논하지 않다 따지지 않다 설사 비록 더라도 아니면 만 못하다 하는 편이 낫다 불문하고 향하여 향해서 향하다 쪽으로 틈타 이용하여 타다 오르다 제외하고 이 외에 이 밖에 하여야 비로소 한다면 몰라도 외에도 이곳 여기 부터 기점으로 따라서 할 생각이다 하려고하다 이리하여 그리하여 그렇게 함으로써 하지만 일때 할때 앞에서 중에서 보는데서 으로써 로써 까지 해야한다 일것이다 반드시 할줄알다 할수있다 할수있어 임에 틀림없다 한다면 등 등등 제 겨우 단지 다만 할뿐 딩동 댕그 대해서 대하여 대하면 훨씬 얼마나 얼마만큼 얼마큼 남짓 여 얼마간 약간 다소 좀 조금 다수 몇 얼마 지만 하물며 또한 그러나 그렇지만 하지만 이외에도 대해 말하자면 뿐이다 다음에 반대로 반대로 말하자면 이와 반대로 바꾸어서 말하면 바꾸어서 한다면 만약 그렇지않으면 까악 툭 딱 삐걱거리다 보드득 비걱거리다 꽈당 응당 해야한다 에 가서 각 각각 여러분 각종 각자 제각기 하도록하다 와 과 그러므로 그래서 고로 한 까닭에 하기 때문에 거니와 이지만 대하여 관하여 관한 과연 실로 아니나다를가 생각한대로 진짜로 한적이있다 하곤하였다 하 하하 허허 아하 거바 와 오 왜 어째서 무엇때문에 어찌 하겠는가 무슨 어디 어느곳 더군다나 하물며 더욱이는 어느때 언제 야 이봐 어이 여보시오 흐흐 흥 휴 헉헉 헐떡헐떡 영차 여차 어기여차 끙끙 아야 앗 아야 콸콸 졸졸 좍좍 뚝뚝 주룩주룩 솨 우르르 그래도 또 그리고 바꾸어말하면 바꾸어말하자면 혹은 혹시 답다 및 그에 따르는 때가 되어 즉 지든지 설령 가령 하더라도 할지라도 일지라도 지든지 몇 거의 하마터면 인젠 이젠 된바에야 된이상 만큼	어찌됏든 그위에 게다가 점에서 보아 비추어 보아 고려하면 하게될것이다 일것이다 비교적 좀 보다더 비하면 시키다 하게하다 할만하다 의해서 연이서 이어서 잇따라 뒤따라 뒤이어 결국 의지하여 기대여 통하여 자마자 더욱더 불구하고 얼마든지 마음대로 주저하지 않고 곧 즉시 바로 당장 하자마자 밖에 안된다 하면된다 그래 그렇지 요컨대 다시 말하자면 바꿔 말하면 즉 구체적으로 말하자면 시작하여 시초에 이상 허 헉 허걱 바와같이 해도좋다 해도된다 게다가 더구나 하물며 와르르 팍 퍽 펄렁 동안 이래 하고있었다 이었다 에서 로부터 까지 예하면 했어요 해요 함께 같이 더불어 마저 마저도 양자 모두 습니다 가까스로 하려고하다 즈음하여 다른 다른 방면으로 해봐요 습니까 했어요 말할것도 없고 무릎쓰고 개의치않고 하는것만 못하다 하는것이 낫다 매 매번 들 모 어느것 어느 로써 갖고말하자면 어디 어느쪽 어느것 어느해 어느 년도 라 해도 언젠가 어떤것 어느것 저기 저쪽 저것 그때 그럼 그러면 요만한걸 그래 그때 저것만큼 그저 이르기까지 할 줄 안다 할 힘이 있다 너 너희 당신 어찌 설마 차라리 할지언정 할지라도 할망정 할지언정 구토하다 게우다 토하다 메쓰겁다 옆사람 퉤 쳇 의거하여 근거하여 의해 따라 힘입어 그 다음 버금 두번째로 기타 첫번째로 나머지는 그중에서 견지에서 형식으로 쓰여 입장에서 위해서 단지 의해되다 하도록시키다 뿐만아니라 반대로 전후 전자 앞의것 잠시 잠깐 하면서 그렇지만 다음에 그러한즉 그런즉 남들 아무거나 어찌하든지 같다 비슷하다 예컨대 이럴정도로 어떻게 만약 만일 위에서 서술한바와같이 인 듯하다 하지 않는다면 만약에 무엇 무슨 어느 어떤 아래윗 조차 한데 그럼에도 불구하고 여전히 심지어 까지도 조차도 하지 않도록 않기 위하여 때 시각 무렵 시간 동안 어때 어떠한 하여금 네 예 우선 누구 누가 알겠는가 아무도 줄은모른다 줄은 몰랏다 하는 김에 겸사겸사 하는바 그런 까닭에 한 이유는 그러니 그러니까 때문에 그 너희 그들 너희들 타인 것 것들 너 위하여 공동으로 동시에 하기 위하여 어찌하여 무엇때문에 붕붕 윙윙 나 우리 엉엉 휘익 윙윙 오호 아하 어쨋든 만 못하다	하기보다는 차라리 하는 편이 낫다 흐흐 놀라다 상대적으로 말하자면 마치 아니라면 쉿 그렇지 않으면 그렇지 않다면 안 그러면 아니었다면 하든지 아니면 이라면 좋아 알았어 하는것도 그만이다 어쩔수 없다 하나 일 일반적으로 일단 한켠으로는 오자마자 이렇게되면 이와같다면 전부 한마디 한항목 근거로 하기에 아울러 하지 않도록 않기 위해서 이르기까지 이 되다 로 인하여 까닭으로 이유만으로 이로 인하여 그래서 이 때문에 그러므로 그런 까닭에 알 수 있다 결론을 낼 수 있다 으로 인하여 있다 어떤것 관계가 있다 관련이 있다 연관되다 어떤것들 에 대해 이리하여 그리하여 여부 하기보다는 하느니 하면 할수록 운운 이러이러하다 하구나 하도다 다시말하면 다음으로 에 있다 에 달려 있다 우리 우리들 오히려 하기는한데 어떻게 어떻해 어찌됏어 어때 어째서 본대로 자 이 이쪽 여기 이것 이번 이렇게말하자면 이런 이러한 이와 같은 요만큼 요만한 것 얼마 안 되는 것 이만큼 이 정도의 이렇게 많은 것 이와 같다 이때 이렇구나 것과 같이 끼익 삐걱 따위 와 같은 사람들 부류의 사람들 왜냐하면 중의하나 오직 오로지 에 한하다 하기만 하면 도착하다 까지 미치다 도달하다 정도에 이르다 할 지경이다 결과에 이르다 관해서는 여러분 하고 있다 한 후 혼자 자기 자기집 자신 우에 종합한것과같이 총적으로 보면 총적으로 말하면 총적으로 대로 하다 으로서 참 그만이다 할 따름이다 쿵 탕탕 쾅쾅 둥둥 봐 봐라 아이야 아니 와아 응 아이 참나 년 월 일 령 영 일 이 삼 사 오 육 륙 칠 팔 구 이천육 이천칠 이천팔 이천구 하나 둘 셋 넷 다섯 여섯 일곱 여덟 아홉 령 영'.split( )
print(stopwords[0])
# Out:
# 도

# %%
# 토큰화하기
total_data['tokenized'] = total_data['reply'].apply(mecab.morphs)
total_data['tokenized'] = total_data['tokenized'].apply(lambda x: [item for item in x if item not in stopwords])

# %%
#단어 분류
words = np.hstack(total_data['tokenized'].values)

# %%
# 단어 빈도 세기
word_count = Counter(words)

# 워드클라우드에 몇개 단어를 넣을지 뒤에 숫자로 조정가능
word_total = word_count.most_common(100)

# 워드클라우드는 딕셔너리로 작동하기 때문에 리스트를 딕셔너리로 변환
word_total = dict(word_total)
print(word_total)
# Out:
# {'원전': 4030, '나라': 990, '탈': 893, '대통령': 875, '적': 656, '안전': 609, '국민': 566, '바보': 556, '문재인': 555, '문': 527, '재앙': 490, '에너지': 438, '잘': 404, '생각': 399, '진짜': 397, '태양광': 385, '세계': 383, '전': 364, '지금': 357, '사람': 340, '만들': 322, '윤': 308, '중국': 303, '시': 300, '전기': 297, '정권': 295, '해라': 282, '경제': 267, '정부': 266, '정책': 262, '던': 261, '국가': 260, '윤석열': 257, '기술': 256, '대한민국': 253, '놓': 251, '무식': 246, '소리': 245, '사고': 243, '환경': 236, '인간': 232, '원자력': 230, '문제': 225, '집': 224, '폐기물': 223, '바보짓': 221, '발전': 220, '후쿠시마': 206, '산업': 204, '간': 201, '죽': 197, '일본': 195, '많': 184, '세요': 179, '인가': 177, '한국': 173, '중': 168, '건설': 167, '처럼': 166, '성': 166, '용산': 165, '어라': 165, '단체': 163, '정신': 162, '민주당': 158, '넘': 157, '산': 157, '수출': 156, '입': 154, '핵': 151, '정말': 150, '미래': 150, '돈': 148, '북한': 147, '입니다': 146, '시키': 146, '길': 145, '열': 140, '며': 140, '처리': 139, '한전': 139, '문재': 137, '이제': 136, '싶': 136, '설치': 135, '친환경': 133, '똥': 133, '화': 131, '찍': 131, '뭘': 130, '탓': 130, '미친': 130, '적자': 130, '수준': 128, '될': 127, '그러': 127, '중시': 126, '방사능': 126, '죠': 125, '반대': 125}

# %%
word_total = dict(word_total)
print(word_total)
# Out:
# {'원전': 4030, '나라': 990, '탈': 893, '대통령': 875, '적': 656, '안전': 609, '국민': 566, '바보': 556, '문재인': 555, '문': 527, '재앙': 490, '에너지': 438, '잘': 404, '생각': 399, '진짜': 397, '태양광': 385, '세계': 383, '전': 364, '지금': 357, '사람': 340, '만들': 322, '윤': 308, '중국': 303, '시': 300, '전기': 297, '정권': 295, '해라': 282, '경제': 267, '정부': 266, '정책': 262, '던': 261, '국가': 260, '윤석열': 257, '기술': 256, '대한민국': 253, '놓': 251, '무식': 246, '소리': 245, '사고': 243, '환경': 236, '인간': 232, '원자력': 230, '문제': 225, '집': 224, '폐기물': 223, '바보짓': 221, '발전': 220, '후쿠시마': 206, '산업': 204, '간': 201, '죽': 197, '일본': 195, '많': 184, '세요': 179, '인가': 177, '한국': 173, '중': 168, '건설': 167, '처럼': 166, '성': 166, '용산': 165, '어라': 165, '단체': 163, '정신': 162, '민주당': 158, '넘': 157, '산': 157, '수출': 156, '입': 154, '핵': 151, '정말': 150, '미래': 150, '돈': 148, '북한': 147, '입니다': 146, '시키': 146, '길': 145, '열': 140, '며': 140, '처리': 139, '한전': 139, '문재': 137, '이제': 136, '싶': 136, '설치': 135, '친환경': 133, '똥': 133, '화': 131, '찍': 131, '뭘': 130, '탓': 130, '미친': 130, '적자': 130, '수준': 128, '될': 127, '그러': 127, '중시': 126, '방사능': 126, '죠': 125, '반대': 125}

# %% [markdown]
# ## 워드클라우드 만들기

# %%
#워드클라우드 왠지모르겠는데 이렇게 해야 열림
from wordcloud import WordCloud

# %%
wordcloud = WordCloud()

font = '/usr/share/fonts/truetype/nanum/NanumGothicBold.ttf'

wc = WordCloud(font_path=font,\
		background_color="white", \
		width=1000, \
		height=1000, \
		max_words=100, \
		max_font_size=300
    )
wc = wc.generate_from_frequencies(word_total)

plt.figure(figsize=(10,10))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

# %% [markdown]
# ## 특정 이미지 & 글자색 바꾸기

# %%
## SET MASK IMAGES
from PIL import Image

url = '/f-4-2.jpg'
# url = '/content/mask.png'
# url = '/content/f4.jpg'
# url = '/content/f35.png'

# mask = Image.open(url)
# mask = np.array(mask)

mask = np.array(Image.open(url))

# %% [markdown]
# ## 워드클라우드 다른 이미지로 만들기

# %%
#https://hipster4020.tistory.com/77

# %%
img = Image.open(url)
main_mask = np.array(img)

# %%
main_mask.shape

# %%
wcloud2 = WordCloud(mask=main_mask,
                    font_path=font,
                    background_color='black')

# %%
wcloud2 = wcloud2.generate_from_frequencies(word_total)
# wcloud2.words_

# %%
plt.figure(figsize=(15,15))
plt.imshow(wcloud2)
plt.axis('off')
plt.show()
