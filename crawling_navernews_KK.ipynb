# %% [markdown]
# # 메모
#
# - 구글뉴스, 네이버뉴스, 네이버블로그, 네이버카페
# - 날짜, 카테고리, 댓글 필요
# - selenium 패키지 보다는 request 방식이 용이

# %%
# Ignore the warnings
import warnings
# warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# Auto reload of library
# %reload_ext autoreload
# %autoreload 2

from data import *

# %%
# search_query = "세대 갈등"
# sort = 0
# start_page = 1
# end_page = 5
#
# url = get_urls_navernews_bypage(search_query, start_page, end_page, sort)
# news = get_navernews(url)

search_query = "고령화"
sort = 0
start_date = "20230601"
end_date = "20230631"

url = get_urls_from_navernews_bydate(search_query, start_date, end_date, sort, maxpage=2)
news = get_data_from_navernews(url)
# Out:
# URL Extracting Time:  0:00:00
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:09<00:00,  3.13s/it]
# News Info Extracting Time:  0:00:09.401655
# Size of News Data:  30

# %%
news
# Out:
#                    Date         Press Category  \
# 0           2023.06.30.        아시아투데이       []
# 1   2023-06-30 05:02:04    경기일보언론사 선정     [사회]
# 2   2023-06-29 14:31:01  아이뉴스24언론사 선정     [사회]
# 3           2023.06.29.          불교신문       []
# 4           2023.06.28.           MTN       []
# 5           2023.06.27.      BBS NEWS       []
# 6           2023.06.27.          경상일보       []
# 7   2023-06-26 15:09:00          한국경제     [사회]
# 8   2023-06-26 11:14:01         헤럴드경제     [사회]
# 9   2023-06-25 15:09:01          시사저널     [사회]
# 10          2023.06.30.          경북신문       []
# 11  2023-06-23 20:20:01          매일경제     [[]]
# 12          2023.06.23.          비즈한국       []
# 13          2023.06.29.     CEO스코어데일리       []
# 14  2023-06-22 17:41:01    이데일리언론사 선정     [사회]
# 15  2023-06-22 15:24:07           뉴시스     [세계]
# 16          2023.06.27.          대구신문       []
# 17  2023-06-21 20:20:01  이코노미스트언론사 선정     [경제]
# 18  2023-06-21 19:07:07     한겨레언론사 선정   [오피니언]
# ...
