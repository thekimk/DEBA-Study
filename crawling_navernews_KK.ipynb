# %% [markdown]
# # 필요메모
#
# - 기고자 불필요
# - 분류 크롤링 필요
# - 기관정보 크롤링 필요
# - 날짜 크롤링(트랜드 필수) + 날짜정보 + 시간정보
# - selenium 패키지 보다는 request 방식이 좋긴한데.. 그래도 데이터를 모을수만 있으면 selenium 오케이1
#
# ---
#
# 4. 데이터 준비
#
# 1) 네이버뉴스+구글뉴스 제목과 본문 + 댓글
#
# 2) 네이버블로그 + 네이버카페 제목과 본문 + 댓글

# %%
# Ignore the warnings
import warnings
# warnings.filterwarnings('always')
warnings.filterwarnings('ignore')

# System related and data input controls
import os

# # Python path
# import sys
# base_folder = 'DataScience'
# location_base = os.path.join(os.getcwd().split(base_folder)[0], base_folder)
# location_module = [os.path.join(location_base, 'Module')] 
# for each in location_module:
#     if each not in sys.path:
#         sys.path.append(each)

# Auto reload of library
# %reload_ext autoreload
# %autoreload 2

from data import *

# %%
import requests
from bs4 import BeautifulSoup

url = "https://n.news.naver.com/mnews/article/015/0004862010?sid=110"

response = requests.get(url)
soup = BeautifulSoup(response.text, 'html.parser')

category_tag = soup.find('a', class_='press_category')
category = category_tag.text.strip() if category_tag else "Category not found"

print("Category:", category)
# Out:
# Category: Category not found

# %%
# search_query = "세대 갈등"
# sort = 0
# start_page = 1
# end_page = 5
#
# url = get_urls_navernews_bypage(search_query, start_page, end_page, sort)
# news = get_navernews(url)

search_query = "세대 갈등"
sort = 0
start_date = "20230601"
end_date = "20230631"

url = get_urls_navernews_bydate(search_query, start_date, end_date, sort, maxpage=2)
news = get_navernews(url)
# Out:
# URL Extracting Time:  0:00:00
#   0%|                                                                                            | 0/3 [00:00<?, ?it/s]
# <span class="Nitem_link_menu">오피니언</span>
# None
# <span class="Nitem_link_menu">경제</span>
# <span class="Nitem_link_menu">오피니언</span>
# <span class="Nitem_link_menu">정치</span>
# <span class="Nitem_link_menu">생활/문화</span>
#  33%|████████████████████████████                                                        | 1/3 [00:03<00:06,  3.47s/it]
# <span class="Nitem_link_menu">사회</span>
#  67%|████████████████████████████████████████████████████████                            | 2/3 [00:04<00:02,  2.09s/it]
# None
# <span class="Nitem_link_menu">사회</span>
# None
# <span class="Nitem_link_menu">정치</span>
# 100%|████████████████████████████████████████████████████████████████████████████████████| 3/3 [00:06<00:00,  2.27s/it]
# News Info Extracting Time:  0:00:06.828684
# Size of News Data:  30

# %%
news
# Out:
#                    Date       Press  \
# 0   2023-06-29 00:26:01  한국경제언론사 선정
# 1           2023.06.27.        기호일보
# 2   2023.06.23. 오전 9:18      엑스포츠뉴스
# 3           2023.06.11.        청년일보
# 4   2023-06-21 04:09:11  국민일보언론사 선정
# 5   2023-06-29 17:25:15        매일경제
# 6           2023.06.14.      미주중앙일보
# 7   2023-06-09 14:23:01  JTBC언론사 선정
# 8   2023-06-08 15:43:07         한겨레
# 9           2023.06.20.      이뉴스투데이
# 10  2023-06-05 12:10:15        문화일보
# 11          2023.06.29.        제주매일
# 12          2023.06.26.        여성동아
# 13          2023.06.26.     스트레이트뉴스
# 14          2023.06.20.        경상일보
# 15          2023.06.28.       노동과세계
# 16          2023.06.21.     서울문화투데이
# 17          2023.06.22.        인사이트
# 18  2023.06.30. 오전 5:58         뉴스엔
# 19          2023.06.24.       뉴스투데이
# 20  2023-06-13 16:01:01  한국일보언론사 선정
# 21  2023.06.21. 오후 5:52       오마이뉴스
# 22          2023.06.14.       아시아에이
# 23          2023.06.21.        약사공론
# 24          2023.06.07.        천지일보
# ...
